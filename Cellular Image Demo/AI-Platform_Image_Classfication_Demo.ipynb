# %% [markdown]
# # Recusion Cellular Image Clasification with AI-Platform

# %% [markdown]
# # How to bring your model to AI Platform
# Getting your model ready for predictions can be done in 5 steps:
# 1. Save your model to a file
# 2. Upload the saved model to [Google Cloud Storage](https://cloud.google.com/storage)
# 3. Create a model resource on AI Platform
# 4. Create a model version
# 5. Make an online prediction

# %% [markdown]
# # Prerequisites
# Before we begin, let’s cover some of the different tools you’ll use to get online prediction up and running on AI Platform.
#
# [Google Cloud Platform](https://cloud.google.com/) (GCP) lets you build and host applications and websites, store data, and analyze data on Google's scalable infrastructure.
#
# [AI Platform](https://cloud.google.com/ml-engine/) is a managed service that enables you to easily build machine learning models that work on any type of data, of any size.
#
# [Google Cloud Storage](https://cloud.google.com/storage/) (GCS) is a unified object storage for developers and enterprises, from live data serving to data analytics/ML to data archiving.
#
# [Cloud SDK](https://cloud.google.com/sdk/) is a command line tool which allows you to interact with Google Cloud products. In order to run this notebook, make sure that Cloud SDK is [installed](https://cloud.google.com/sdk/downloads) in the same environment as your Jupyter kernel.

# %%
# %env PROJECT_ID=mwpmltr
# %env BUCKET_ID=cellular_img_demo
# %env PACKAGE_PATH=trainer
# %env MODULE_NAME=trainer.task
# %env RUNTIME_VERSION=1.15
# %env PYTHON_VERSION=3.7
# %env REGION=us-central1
# Out:
# env: PROJECT_ID=mwpmltr
# env: BUCKET_ID=cellular_img_demo
# env: PACKAGE_PATH=trainer
# env: MODULE_NAME=trainer.task
# env: RUNTIME_VERSION=1.15
# env: PYTHON_VERSION=3.7
# env: REGION=us-central1

# %%
# Create BUCKET_NAME if it does not exist.
# !gsutil mb gs://${BUCKET_ID}
# Out:
# Creating gs://cellular_img_demo/...

# %%
#copy data to the bucket

#This might take a while as we are copying images
# !gsutil -m cp -r gs://cellular-model-bucket/data gs://${BUCKET_ID}/data
# Out:
# Copying gs://cellular-model-bucket/data/DenseNet.h5 [Content-Type=application/octet-stream]...
# Copying gs://cellular-model-bucket/data/NWDATA/test/B02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_B23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_C20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_D14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_E20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_F20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_G23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_H13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_I20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_J23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_K23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_L22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_M17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_N20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate1_O20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_B23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_C23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_D23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_E23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_F23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_G23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_H21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/HEPG2-01_Plate2_I18_s1_w1.png [Content-Type=image/png]...
# ...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_H20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_H23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_I23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_J23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_K21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_L23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_M23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N22_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_N23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O05_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O02_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O07_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O04_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O06_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O03_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O08_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O12_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O13_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O09_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O10_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O11_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O16_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O14_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O15_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O17_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O21_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O18_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O19_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O20_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O23_s1_w1.png [Content-Type=image/png]...
# Copying gs://cellular-model-bucket/data/new_train.csv [Content-Type=application/octet-stream]...
# Copying gs://cellular-model-bucket/data/NWDATA/train/U2OS-01_Plate4_O22_s1_w1.png [Content-Type=image/png]...
# / [3.3k/3.3k files][252.6 MiB/252.6 MiB]  99% Done   3.0 MiB/s ETA 00:00:00

# %%
now = !date +"%Y%m%d_%H%M%S"
# %env JOB_NAME=tensorflow_job_$now.s

# !gcloud ai-platform jobs submit training $JOB_NAME \
  --package-path trainer/ \
  --module-name trainer.task \
  --region $REGION \
  --python-version 3.7 \
  --runtime-version 2.1 \
  --job-dir gs://${BUCKET_ID}/keras-job-dir-${JOB_NAME} \
  -- \
  --project-id $PROJECT_ID \
  --bucket-name ${BUCKET_ID} 
                
# Stream logs so that training is done before subsequent cells are run.
# Remove  '> /dev/null' to see step-by-step output of the model build steps.
# !gcloud ai-platform jobs stream-logs $JOB_NAME > /dev/null

# Model should exit with status "SUCCEEDED"
# !gcloud ai-platform jobs describe $JOB_NAME --format="value(state)"
# Out:
# env: JOB_NAME=tensorflow_job_20200901_100731
# Job [tensorflow_job_20200901_100731] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ai-platform jobs describe tensorflow_job_20200901_100731
#
# or continue streaming the logs with the command
#
#   $ gcloud ai-platform jobs stream-logs tensorflow_job_20200901_100731
# jobId: tensorflow_job_20200901_100731
# state: QUEUED
# SUCCEEDED
