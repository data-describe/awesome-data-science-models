# %% [markdown]
# <b>Define environment variables</b>
#
# To be used in future training steps.  Note that the BUCKET_NAME defined below must exist in the GCP project.

# %%
# %env BUCKET_NAME=ml-workshop-chicago-taxi-demo
# %env LOCAL_JOB_DIR=local-training-output
# %env JOB_NAME=keras_job_1
# %env REGION=us-central1
# %env MODEL_NAME=keras_model_1
# %env MODEL_VERSION=v4
# %env PROJECT_ID=mwe-sanofi-ml-workshop
# Out:
# env: BUCKET_NAME=ml-workshop-chicago-taxi-demo
# env: LOCAL_JOB_DIR=local-training-output
# env: JOB_NAME=keras_job_6_0611
# env: REGION=us-central1
# env: MODEL_NAME=keras_model_1_0611
# env: MODEL_VERSION=v4
# env: PROJECT_ID=mwe-sanofi-ml-workshop

# %%
# Create BUCKET_NAME if it does not exist.
# !gsutil mb gs://${BUCKET_NAME}
# Out:
# Creating gs://ml-workshop-chicago-taxi-demo/...

# %% [markdown]
# <b>Perform training locally with default parameters</b>
#
# Training detail will be written locally to the folder referenced in the job-dir parameter.
#
# Note - creating the data will take some time as the MinMax normalizer needs to be fit over the 100 M plus training rows.

# %%
# Set --create-data=False after first run. Only needs to be run once for this cell.
# !gcloud ai-platform local train \
  --package-path trainer \
  --module-name trainer.task \
  --job-dir $LOCAL_JOB_DIR \
  -- \
  --create-data=True

# %% [markdown]
# <b>Perform training on AI Platform</b>
#
# The training job can also be run on AI Platform.  Note that in order for AI Platform to be able to complete the training job, the "Google Cloud ML Engine Service Agent" service account must be granted Cloud Storage and BigQuery admin roles.
#
# Important: A single training job (either locally or using AI Platform) must complete with the create-data flag set to true for the remainig functionality to compolete.

# %%
# Set --create-data=False after first run. Only needs to be run once for this cell.
# !gcloud ai-platform jobs submit training $JOB_NAME \
  --package-path trainer/ \
  --module-name trainer.task \
  --region $REGION \
  --python-version 3.5 \
  --runtime-version 1.13 \
  --job-dir gs://${BUCKET_NAME}/keras-job-dir-${JOB_NAME} \
  -- \
  --create-data=True
# Out:
# Job [keras_job_1_0611] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ai-platform jobs describe keras_job_1_0611
#
# or continue streaming the logs with the command
#
#   $ gcloud ai-platform jobs stream-logs keras_job_1_0611
# jobId: keras_job_1_0611
# state: QUEUED

# %% [markdown]
# <b>Perform hyperparameter tuning on AI Platform</b>
#
# Training detail will be written to Cloud Storage in the folder referenced in the job-dir parameter

# %%
# !gcloud ai-platform jobs submit training ${JOB_NAME}_hpt \
  --config hptuning_config.yaml \
  --package-path trainer/ \
  --module-name trainer.task \
  --region $REGION \
  --python-version 3.5 \
  --runtime-version 1.13 \
  --job-dir gs://${BUCKET_NAME}/keras-job-dir-${JOB_NAME}_hpt
# Out:
# Job [keras_job_4_0611_hpt] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ai-platform jobs describe keras_job_4_0611_hpt
#
# or continue streaming the logs with the command
#
#   $ gcloud ai-platform jobs stream-logs keras_job_4_0611_hpt
# jobId: keras_job_4_0611_hpt
# state: QUEUED

# %% [markdown]
# <b>Complete training on AI Platform</b>
#
# Now that hyperparameters have been tuned, perform deeper training with the optimal hyperparameters in place.  Note that we've explicitly increased the train-steps and num-epochs parameters in addition to the tuned hyperparameters.

# %%
# Set --create-data=False after first run. Only needs to be run once for this cell.
# !gcloud ai-platform jobs submit training $JOB_NAME \
  --package-path trainer/ \
  --module-name trainer.task \
  --region $REGION \
  --python-version 3.5 \
  --runtime-version 1.13 \
  --job-dir gs://${BUCKET_NAME}/keras-job-dir-${JOB_NAME} \
  -- \
  --project-id $PROJECT_ID \
  --bucket-name ${BUCKET_NAME} \
  --create-data=True \
  --test-files gs://${BUCKET_NAME}/data/full_test_results.csv \
  --train-files gs://${BUCKET_NAME}/data/full_train_results.csv \
  --eval-files gs://${BUCKET_NAME}/data/full_val_results.csv \
  --num-deep-layers=2 \
  --first-deep-layer-size=30 \
  --first-wide-layer-size=1233 \
  --learning-rate=0.003 \
  --wide-scale-factor=0.094 \
  --train-batch-size=132 \
  --dropout-rate=0.4 \
  --train-steps=10 \
  --num-epochs=5
# Out:
# Job [keras_job_6_0611] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ai-platform jobs describe keras_job_6_0611
#
# or continue streaming the logs with the command
#
#   $ gcloud ai-platform jobs stream-logs keras_job_6_0611
# jobId: keras_job_6_0611
# state: QUEUED

# %% [markdown]
# <b>Host the trained model on AI Platform</b>
#
# Because we're passing a list of numpy arrays and not a single numpy array as input for inference, we'll need to establish a custom prediction module.
#
# First, execute the setup script to create a distribution tarball

# %%
# !python setup.py sdist --formats=gztar
# Out:
# running sdist
# running egg_info
# creating trainer.egg-info
# writing trainer.egg-info/PKG-INFO
# writing dependency_links to trainer.egg-info/dependency_links.txt
# writing requirements to trainer.egg-info/requires.txt
# writing top-level names to trainer.egg-info/top_level.txt
# writing manifest file 'trainer.egg-info/SOURCES.txt'
# reading manifest file 'trainer.egg-info/SOURCES.txt'
# writing manifest file 'trainer.egg-info/SOURCES.txt'
# running check
# warning: check: missing required meta-data: url
#
# warning: check: missing meta-data: either (author and author_email) or (maintainer and maintainer_email) must be supplied
#
# creating trainer-0.1
# creating trainer-0.1/trainer
# creating trainer-0.1/trainer.egg-info
# copying files to trainer-0.1...
# copying README.md -> trainer-0.1
# copying predictor.py -> trainer-0.1
# copying setup.py -> trainer-0.1
# copying trainer/__init__.py -> trainer-0.1/trainer
# copying trainer/create_data_func.py -> trainer-0.1/trainer
# copying trainer/create_scaler_func.py -> trainer-0.1/trainer
# copying trainer/model.py -> trainer-0.1/trainer
# copying trainer/task.py -> trainer-0.1/trainer
# copying trainer.egg-info/PKG-INFO -> trainer-0.1/trainer.egg-info
# copying trainer.egg-info/SOURCES.txt -> trainer-0.1/trainer.egg-info
# copying trainer.egg-info/dependency_links.txt -> trainer-0.1/trainer.egg-info
# copying trainer.egg-info/requires.txt -> trainer-0.1/trainer.egg-info
# copying trainer.egg-info/top_level.txt -> trainer-0.1/trainer.egg-info
# Writing trainer-0.1/setup.cfg
# creating dist
# Creating tar archive
# removing 'trainer-0.1' (and everything under it)

# %% [markdown]
# Copy the tarball over to Cloud Storage

# %%
# !gsutil cp dist/trainer-0.1.tar.gz gs://${BUCKET_NAME}/staging-dir/trainer-0.1.tar.gz
# Out:
# Copying file://dist/trainer-0.1.tar.gz [Content-Type=application/x-tar]...
# / [1 files][  9.2 KiB/  9.2 KiB]
# Operation completed over 1 objects/9.2 KiB.

# %% [markdown]
# Next, create a new model on AI Platform

# %%
# !gcloud ai-platform models create $MODEL_NAME --regions $REGION
# Out:
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Created ml engine model [projects/mwe-sanofi-ml-workshop/models/keras_model_1_0611].

# %% [markdown]
# Next we create new version using our trained model

# %%
# !gcloud beta ai-platform versions create $MODEL_VERSION \
  --model $MODEL_NAME \
  --runtime-version 1.13 \
  --python-version 3.5 \
  --origin gs://${BUCKET_NAME}/keras-job-dir-${JOB_NAME} \
  --package-uris gs://${BUCKET_NAME}/staging-dir/trainer-0.1.tar.gz \
  --prediction-class predictor.MyPredictor
# Out:
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Creating version (this might take a few minutes)......done.

# %% [markdown]
# <b>Prepare a sample for inference</b>
#
# Note that we are using the same preprocessing methods used for training.

# %%
# !python create_sample.py
# Out:
# Using TensorFlow backend.
# Downloading: 100%|██████████████████████████████| 7/7 [00:00<00:00, 68.52rows/s]
# Downloading: 100%|██████████████████████████████| 2/2 [00:00<00:00, 17.27rows/s]
# Downloading: 100%|██████████████████████████████| 5/5 [00:00<00:00, 47.36rows/s]
# Downloading: 100%|██████████████████████████████| 4/4 [00:00<00:00, 60.69rows/s]
# Downloading: 100%|███████████████████████████| 61/61 [00:00<00:00, 563.05rows/s]
# Produced sample with label 720 seconds.

# %% [markdown]
# <b>Make an inference on a new sample.</b>
#
# Pass the sample object to the model hosted in AI Platform to return a prediction.

# %%
# !gcloud ai-platform predict \
  --model $MODEL_NAME \
  --version $MODEL_VERSION \
  --json-instances input_sample.json
# Out:
# WARNING: Using endpoint [https://ml.googleapis.com/]
# {
#   "predictions": "26.667124910417414"
# }

# %% [markdown]
# <b>Approximate an Mean Absolute Percentage Error for the test set</b>
#
# Note that we used a log transformation on our target variable, so any attributes returned by the model during training will be associated with predicting the <i>log</i> of the trip duration and not the actual trip duration.  In order to calculate metrics associated with predicting the trip duration in seconds, we'll need to make predictions from the test set using our trained model.
#
# The best case scenario here would be to use the batch prediction within AI Platform.  However, batch prediction is not currently available with the custom predictor module we've implented.
#
# As an alternativel we'll approximate the MAPE by randomly sampling values from the test set.

# %%
# !python calc_mape.py \
  --num-samples=1000 \
  --model=$MODEL_NAME \
  --version=$MODEL_VERSION \
  --project-id $PROJECT_ID \
  --bucket-name ${BUCKET_NAME}
# Out:
# Using TensorFlow backend.
# Downloading: 100%|██████████████████████████████| 7/7 [00:00<00:00, 61.68rows/s]
# Downloading: 100%|██████████████████████████████| 2/2 [00:00<00:00,  7.39rows/s]
# Downloading: 100%|██████████████████████████████| 5/5 [00:00<00:00, 48.22rows/s]
# Downloading: 100%|██████████████████████████████| 4/4 [00:00<00:00, 40.01rows/s]
# Downloading: 100%|███████████████████████████| 61/61 [00:00<00:00, 524.94rows/s]
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 3480 and prediction 73.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 66.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 75.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1920 and prediction 135.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1500 and prediction 44.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1860 and prediction 243.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 34.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 25.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 25.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 180 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 180 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 120 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 37.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 300 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 300 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 120 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 180 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 180 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 300 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2220 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 8.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2940 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1800 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2040 and prediction 6.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2040 and prediction 6.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1380 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 6.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2580 and prediction 6.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2700 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2160 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1440 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2520 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 6.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2040 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 3360 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 3000 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1260 and prediction 6.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2400 and prediction 6.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 7.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1260 and prediction 6.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1440 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 37.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 37.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1500 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 300 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 37.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 37.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2220 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1500 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 180 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 37.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1500 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 300 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 300 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 32.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1560 and prediction 29.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 27.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 31.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 39.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 38.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2280 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2520 and prediction 40.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 16.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1860 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1560 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1260 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1920 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1440 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1500 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1440 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1860 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1260 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 9.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1260 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1260 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 12.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1620 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 13.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 10.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 11.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1500 and prediction 13.
# ...
# Returned sample with label 780 and prediction 319.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 402.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 301.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1380 and prediction 330.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 278.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1260 and prediction 277.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 303.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 402.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 299.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 331.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 330.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1680 and prediction 278.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 301.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 301.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1620 and prediction 278.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 4800 and prediction 99.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 63.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 153.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 198.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1620 and prediction 157.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 127.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 175.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 112.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 3960 and prediction 132.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 175.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 164.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 134.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 134.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 112.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 132.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 133.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 176.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2160 and prediction 133.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 129.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 165.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 127.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1620 and prediction 126.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 133.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 166.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 165.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1620 and prediction 54.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2580 and prediction 52.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 2340 and prediction 48.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 77.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 99.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 108.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 78.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1800 and prediction 77.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 78.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 106.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 108.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 108.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 77.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 83.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 83.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 106.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 78.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 77.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 300 and prediction 77.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 300 and prediction 84.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 83.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 78.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 78.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 77.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 107.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 83.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 83.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 83.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 84.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 117.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 121.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 123.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 107.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 163.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 107.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1740 and prediction 107.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1980 and prediction 118.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 118.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 660 and prediction 108.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 118.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 118.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 121.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 840 and prediction 158.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 159.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 123.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 107.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1260 and prediction 361.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1500 and prediction 264.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1680 and prediction 265.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 245.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 266.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 284.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1980 and prediction 123.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 91.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 46.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 60 and prediction 114.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 180 and prediction 80.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 3000 and prediction 1106.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 180 and prediction 1420.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 300 and prediction 1406.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 60 and prediction 1049.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 1042.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 1422.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 6360 and prediction 1851.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 946.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 240 and prediction 1030.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 946.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 60 and prediction 1088.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 1436.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1740 and prediction 328.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 383.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 1595.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1920 and prediction 320.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1200 and prediction 1152.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 1640.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1380 and prediction 1143.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 2760.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 2026.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 1891.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 2031.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 720 and prediction 1888.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 420 and prediction 2591.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 1405.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 1940.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1080 and prediction 1942.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 900 and prediction 1315.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1320 and prediction 1334.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 4020 and prediction 1147.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 960 and prediction 1153.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1980 and prediction 508.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 306.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1020 and prediction 273.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 360 and prediction 273.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 437.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 180 and prediction 331.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 480 and prediction 432.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 505.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1140 and prediction 379.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1260 and prediction 350.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 358.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 506.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 305.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1500 and prediction 303.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 540 and prediction 295.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1740 and prediction 258.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1560 and prediction 233.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1980 and prediction 259.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 3180 and prediction 275.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 1920 and prediction 212.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 360.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 429.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 600 and prediction 337.
# WARNING: Using endpoint [https://ml.googleapis.com/]
# Returned sample with label 780 and prediction 335.
# MAPE across 1000 test samples is 88%.
