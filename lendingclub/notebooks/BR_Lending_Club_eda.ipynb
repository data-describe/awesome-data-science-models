# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("gs://sanofi-ml-workshop-lending-club/data/DR_Demo_Lending_Club.csv")

# %%
data.head(1)
# Out:
#    Id  is_bad          emp_title emp_length home_ownership  annual_inc  \
# 0   1       0  Time Warner Cable         10       MORTGAGE     50000.0
#
#   verification_status pymnt_plan Notes purpose_cat  ...  \
# 0        not verified          n   NaN     medical  ...
#
#   mths_since_last_record open_acc pub_rec  revol_bal  revol_util total_acc  \
# 0                    NaN     15.0     0.0      12087        12.1      44.0
#
#    initial_list_status  collections_12_mths_ex_med  \
# 0                    f                         0.0
#
#    mths_since_last_major_derog  policy_code
# 0                            1          PC4
#
# [1 rows x 28 columns]
